# %% [markdown]
# ### 변수

# %%
# 데이터를 담아두는 그릇 = 변수
a = 10  # a라는 그릇에 10이라는 데이터를 담아두겠다.
b = 3   # b라는 그릇에 3이라는 데이터를 담아두겠다.
a + b   # a 그릇에 담긴 데이터와 b 그릇에 담긴 데이터를 더하라
# Out:
# 13

# %%
c = a + b  # a 그릇과 b 그릇에 담긴 데이터를 더한 결과를 c 그릇에 담아두겠다.
c
# Out:
# 13

# %%
c = c + 5  # c 그릇에 담긴 데이터에 5를 더한 결과를 다시 c 그릇에 담아두겠다. c += 5 와 동일.
c
# Out:
# 18

# %%
# 변수명명 규칙

# 영문(대소문자 구분), 숫자, 언더스코어(_) 사용 가능
# 숫자로 시작할 수 없음
# 공백 사용 불가
# 특수문자 사용 불가 (!, @, #, $, %, ^, &, *, (, ), -, +, = 등)
# 파이썬 예약어(키워드)는 사용 불가 (if, else, for, while, def, return 등)
# python은 snake_case 권장 (단어와 단어 사이는 언더스코어(_)로 연결)
# 가급적 의미 있는 이름 사용 (ex. total_score, user_name 등)

# %%
age = 20
grade = 4.5
total_score = 450

# %%
# 두개의 값 교환하기
a = 10
b = 20
print(a, b)
tmp = a
a = b
b = tmp
print(a, b)
# Out:
# 10 20
# 20 10

# %%
# 두개의 값 교환하기
a = 10
b = 20
print(a, b)
a, b = b, a
print(a, b)
# Out:
# 10 20
# 20 10

# %%
# 동시에 여러 값 선언
a = b = 10
print(a, b)
# Out:
# 10 10

# %%
# EOD.
