# %% [markdown]
# ### 프로그램 입출력

# %%
# 터미널에서 입력 값 받을 때 활용
# python 파일명.py [입력1] [입력2]

# %%
import sys
args = sys.argv[1:]
for i in args:
    print(i.upper(), end = ' ')
# Out:
# --F=/USERS/KMY/LIBRARY/JUPYTER/RUNTIME/KERNEL-V31BF8EE84E94B1318CEA818F08BE5F09BB5940CB5.JSON

# %%
# EOD.
