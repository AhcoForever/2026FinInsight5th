# %%
# !pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in ./.venv/lib/python3.13/site-packages (1.8.0)
# Requirement already satisfied: numpy>=1.24.1 in ./.venv/lib/python3.13/site-packages (from scikit-learn) (2.4.0)
# Requirement already satisfied: scipy>=1.10.0 in ./.venv/lib/python3.13/site-packages (from scikit-learn) (1.17.0)
# Requirement already satisfied: joblib>=1.3.0 in ./.venv/lib/python3.13/site-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in ./.venv/lib/python3.13/site-packages (from scikit-learn) (3.6.0)
#
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip

# %%
import pandas as pd
from sklearn.neighbors import KNeighborsClassifier
from sklearn import metrics
import matplotlib.pyplot as plt

bmi_data =pd.read_csv('data/bmi_500.csv')
bmi_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Gender  500 non-null    object
#  1   Height  500 non-null    int64
#  2   Weight  500 non-null    int64
#  3   Label   500 non-null    object
# dtypes: int64(2), object(2)
# memory usage: 15.8+ KB

# %%
bmi_data['Gender'].value_counts()
# Out:
# Gender
# Female    255
# Male      245
# Name: count, dtype: int64

# %%
bmi_data.index.unique()
# Out:
# RangeIndex(start=0, stop=500, step=1)

# %%
bmi_data.describe()
# Out:
#            Height      Weight
# count  500.000000  500.000000
# mean   169.944000  106.000000
# std     16.375261   32.382607
# min    140.000000   50.000000
# 25%    156.000000   80.000000
# 50%    170.500000  106.000000
# 75%    184.000000  136.000000
# max    199.000000  160.000000

# %%
plt.scatter(
    bmi_data['Weight'],
    bmi_data['Height']
)

# %%
def myScatter(class_name, color):
    class_data = bmi_data.loc[class_name]
    plt.scatter(
        class_data['Weight'],
        class_data['Height'],
        c = color,
        labe = class_name
    )

# %%
bmi_data.head()
# Out:
#    Gender  Height  Weight       Label
# 0    Male     174      96     Obesity
# 1    Male     189      87      Normal
# 2  Female     185     110     Obesity
# 3  Female     195     104  Overweight
# 4    Male     149      61  Overweight
